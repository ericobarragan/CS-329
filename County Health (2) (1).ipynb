# %% [markdown]
# # Health Data

# %% [markdown]
# #### Reading in XLSX files

# %%
import pandas as pd

df1 = pd.read_excel('2023_California_County_Health.xlsx', sheet_name = 3, header = 1)
df2 = pd.read_excel('2023_Texas_County_Health.xlsx', sheet_name = 3, header = 1)
df3 = pd.read_excel('2023_New_York_County_Health.xlsx', sheet_name = 3, header = 1)

# %% [markdown]
# #### Creating new DFs with Columns of Interest

# %%
# California Data

ca = df1[['FIPS', 'State', 'County', 'Unreliable','% Fair or Poor Health', 'Average Number of Physically Unhealthy Days', 'Average Number of Mentally Unhealthy Days', '% Low Birthweight', '% Adults with Obesity', 'Food Environment Index', '% Physically Inactive', '% With Access to Exercise Opportunities', '% Driving Deaths with Alcohol Involvement', 'Average Daily PM2.5', '% Drive Alone to Work', '% Long Commute - Drives Alone']]
ca.head()
# Out:
#    FIPS       State   County Unreliable  % Fair or Poor Health  \
# 0  6000  California      NaN        NaN                   14.4
# 1  6001  California  Alameda        NaN                   11.7
# 2  6003  California   Alpine          x                   13.0
# 3  6005  California   Amador        NaN                   13.4
# 4  6007  California    Butte        NaN                   15.4
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     2.964399
# 1                                     2.592017
# 2                                     3.216721
# 3                                     3.243942
# 4                                     3.543488
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 0                                   4.030544           6.889022
# 1                                   4.521002           7.154935
# 2                                   4.904033                NaN
# ...

# %%
# Texas Data

tx = df2[['FIPS', 'State', 'County', 'Unreliable','% Fair or Poor Health', 'Average Number of Physically Unhealthy Days', 'Average Number of Mentally Unhealthy Days', '% Low Birthweight', '% Adults with Obesity', 'Food Environment Index', '% Physically Inactive', '% With Access to Exercise Opportunities', '% Driving Deaths with Alcohol Involvement', 'Average Daily PM2.5', '% Drive Alone to Work', '% Long Commute - Drives Alone']]
tx.head()
# Out:
#     FIPS  State    County Unreliable  % Fair or Poor Health  \
# 0  48000  Texas       NaN        NaN                   15.7
# 1  48001  Texas  Anderson        NaN                   19.8
# 2  48003  Texas   Andrews        NaN                   19.7
# 3  48005  Texas  Angelina        NaN                   20.6
# 4  48007  Texas   Aransas        NaN                   19.7
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     2.922101
# 1                                     3.878645
# 2                                     3.778131
# 3                                     4.068346
# 4                                     4.043917
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 0                                   4.175881           8.341789
# 1                                   4.725674           7.356547
# 2                                   4.708524           7.317073
# ...

# %%
# New York Data

ny = df3[['FIPS', 'State', 'County', 'Unreliable','% Fair or Poor Health', 'Average Number of Physically Unhealthy Days', 'Average Number of Mentally Unhealthy Days', '% Low Birthweight', '% Adults with Obesity', 'Food Environment Index', '% Physically Inactive', '% With Access to Exercise Opportunities', '% Driving Deaths with Alcohol Involvement', 'Average Daily PM2.5', '% Drive Alone to Work', '% Long Commute - Drives Alone']]
ny.head()
# Out:
#     FIPS     State    County Unreliable  % Fair or Poor Health  \
# 0  36000  New York       NaN        NaN                   11.8
# 1  36001  New York    Albany        NaN                   10.4
# 2  36003  New York  Allegany        NaN                   12.6
# 3  36005  New York     Bronx        NaN                   20.9
# 4  36007  New York    Broome        NaN                   12.7
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     2.709460
# 1                                     2.554739
# 2                                     3.251573
# 3                                     3.531088
# 4                                     3.256628
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 0                                   4.118401           7.992528
# 1                                   4.347739           8.120394
# 2                                   4.921041           6.731352
# ...

# %%
print(ca.shape)
print(tx.shape)
print(ny.shape)
# Out:
# (59, 16)
# (255, 16)
# (63, 16)

# %% [markdown]
# #### Column Names

# %%
ca.dtypes
# Out:
# FIPS                                             int64
# State                                           object
# County                                          object
# Unreliable                                      object
# % Fair or Poor Health                          float64
# Average Number of Physically Unhealthy Days    float64
# Average Number of Mentally Unhealthy Days      float64
# % Low Birthweight                              float64
# % Adults with Obesity                          float64
# Food Environment Index                         float64
# % Physically Inactive                          float64
# % With Access to Exercise Opportunities        float64
# % Driving Deaths with Alcohol Involvement      float64
# Average Daily PM2.5                            float64
# % Drive Alone to Work                          float64
# % Long Commute - Drives Alone                  float64
# dtype: object

# %%
tx.dtypes
# Out:
# FIPS                                             int64
# State                                           object
# County                                          object
# Unreliable                                      object
# % Fair or Poor Health                          float64
# Average Number of Physically Unhealthy Days    float64
# Average Number of Mentally Unhealthy Days      float64
# % Low Birthweight                              float64
# % Adults with Obesity                          float64
# Food Environment Index                         float64
# % Physically Inactive                          float64
# % With Access to Exercise Opportunities        float64
# % Driving Deaths with Alcohol Involvement      float64
# Average Daily PM2.5                            float64
# % Drive Alone to Work                          float64
# % Long Commute - Drives Alone                  float64
# dtype: object

# %%
ny.dtypes
# Out:
# FIPS                                             int64
# State                                           object
# County                                          object
# Unreliable                                      object
# % Fair or Poor Health                          float64
# Average Number of Physically Unhealthy Days    float64
# Average Number of Mentally Unhealthy Days      float64
# % Low Birthweight                              float64
# % Adults with Obesity                          float64
# Food Environment Index                         float64
# % Physically Inactive                          float64
# % With Access to Exercise Opportunities        float64
# % Driving Deaths with Alcohol Involvement      float64
# Average Daily PM2.5                            float64
# % Drive Alone to Work                          float64
# % Long Commute - Drives Alone                  float64
# dtype: object

# %% [markdown]
# #### Distribution of columns

# %%
ca.describe()
# Out:
#               FIPS  % Fair or Poor Health  \
# count    59.000000              59.000000
# mean   6057.016949              15.372881
# std      34.322252               3.307819
# min    6000.000000               9.500000
# 25%    6028.000000              13.100000
# 50%    6057.000000              14.700000
# 75%    6086.000000              17.300000
# max    6115.000000              24.000000
#
#        Average Number of Physically Unhealthy Days  \
# count                                    59.000000
# mean                                      3.371566
# std                                       0.446369
# min                                       2.450219
# 25%                                       3.046148
# 50%                                       3.389837
# 75%                                       3.735116
# max                                       4.161616
#
#        Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# ...

# %%
# Find Range of each column

print('Range of % Fair or Poor Health:',ca['% Fair or Poor Health'].max()-ca['% Fair or Poor Health'].min())
print('Range of Average Number of Physically Unhealthy Days:',ca['Average Number of Physically Unhealthy Days'].max()-ca['Average Number of Physically Unhealthy Days'].min())
print('Range of Average Number of Mentally Unhealthy Days:',ca['Average Number of Mentally Unhealthy Days'].max()-ca['Average Number of Mentally Unhealthy Days'].min())
print('Range of % Low Birthweight:',ca['% Low Birthweight'].max()-ca['% Low Birthweight'].min())
print('Range of % Adults with Obesity:',ca['% Adults with Obesity'].max()-ca['% Adults with Obesity'].min())
print('Range of Food Environment Index:',ca['Food Environment Index'].max()-ca['Food Environment Index'].min())
print('Range of % Physically Inactive:',ca['% Physically Inactive'].max()-ca['% Physically Inactive'].min())
print('Range of % With Access to Exercise Opportunities:',ca['% With Access to Exercise Opportunities'].max()-ca['% With Access to Exercise Opportunities'].min())
print('Range of % Driving Deaths with Alcohol Involvement:',ca['% Driving Deaths with Alcohol Involvement'].max()-ca['% Driving Deaths with Alcohol Involvement'].min())
print('Range of Average Daily PM2.5:',ca['Average Daily PM2.5'].max()-ca['Average Daily PM2.5'].min())
print('Range of % Drive Alone to Work',ca['% Drive Alone to Work'].max()-ca['% Drive Alone to Work'].min())
print('Range of % Long Commute - Drives Alone',ca['% Long Commute - Drives Alone'].max()-ca['% Long Commute - Drives Alone'].min())
# Out:
# Range of % Fair or Poor Health: 14.5
# Range of Average Number of Physically Unhealthy Days: 1.7113971754000001
# Range of Average Number of Mentally Unhealthy Days: 1.5374495411
# Range of % Low Birthweight: 3.996263205799999
# Range of % Adults with Obesity: 20.1
# Range of Food Environment Index: 3.3000000000000007
# Range of % Physically Inactive: 17.6
# Range of % With Access to Exercise Opportunities: 92.9542645241
# Range of % Driving Deaths with Alcohol Involvement: 50.046082949500004
# Range of Average Daily PM2.5: 12.5
# Range of % Drive Alone to Work 52.546286959
# Range of % Long Commute - Drives Alone 42.5

# %%
tx.describe()
# Out:
#                FIPS  % Fair or Poor Health  \
# count    255.000000             254.000000
# mean   48253.003922              19.562205
# std      147.505945               4.197005
# min    48000.000000              10.900000
# 25%    48126.000000              17.000000
# 50%    48253.000000              19.350000
# 75%    48380.000000              21.300000
# max    48507.000000              36.800000
#
#        Average Number of Physically Unhealthy Days  \
# count                                   254.000000
# mean                                      3.863821
# std                                       0.444153
# min                                       2.651345
# 25%                                       3.605398
# 50%                                       3.892371
# 75%                                       4.082342
# max                                       5.639314
#
#        Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# ...

# %%
# Find Range of each column

print('Range of % Fair or Poor Health:',tx['% Fair or Poor Health'].max()-tx['% Fair or Poor Health'].min())
print('Range of Average Number of Physically Unhealthy Days:',tx['Average Number of Physically Unhealthy Days'].max()-tx['Average Number of Physically Unhealthy Days'].min())
print('Range of Average Number of Mentally Unhealthy Days:',tx['Average Number of Mentally Unhealthy Days'].max()-tx['Average Number of Mentally Unhealthy Days'].min())
print('Range of % Low Birthweight:',tx['% Low Birthweight'].max()-tx['% Low Birthweight'].min())
print('Range of % Adults with Obesity:',tx['% Adults with Obesity'].max()-tx['% Adults with Obesity'].min())
print('Range of Food Environment Index:',tx['Food Environment Index'].max()-tx['Food Environment Index'].min())
print('Range of % Physically Inactive:',tx['% Physically Inactive'].max()-tx['% Physically Inactive'].min())
print('Range of % With Access to Exercise Opportunities:',tx['% With Access to Exercise Opportunities'].max()-tx['% With Access to Exercise Opportunities'].min())
print('Range of % Driving Deaths with Alcohol Involvement:',tx['% Driving Deaths with Alcohol Involvement'].max()-tx['% Driving Deaths with Alcohol Involvement'].min())
print('Range of Average Daily PM2.5:',tx['Average Daily PM2.5'].max()-tx['Average Daily PM2.5'].min())
print('Range of % Drive Alone to Work',tx['% Drive Alone to Work'].max()-tx['% Drive Alone to Work'].min())
print('Range of % Long Commute - Drives Alone',tx['% Long Commute - Drives Alone'].max()-tx['% Long Commute - Drives Alone'].min())
# Out:
# Range of % Fair or Poor Health: 25.9
# Range of Average Number of Physically Unhealthy Days: 2.9879696937
# Range of Average Number of Mentally Unhealthy Days: 1.5633774392
# Range of % Low Birthweight: 7.3642101982
# Range of % Adults with Obesity: 18.5
# Range of Food Environment Index: 7.6
# Range of % Physically Inactive: 26.8
# Range of % With Access to Exercise Opportunities: 97.728147863
# Range of % Driving Deaths with Alcohol Involvement: 100.0
# Range of Average Daily PM2.5: 5.9
# Range of % Drive Alone to Work 36.605438931
# Range of % Long Commute - Drives Alone 65.2

# %%
ny.describe()
# Out:
#                FIPS  % Fair or Poor Health  \
# count     63.000000              63.000000
# mean   36061.015873              12.044444
# std       36.633535               1.710195
# min    36000.000000               9.000000
# 25%    36030.000000              11.150000
# 50%    36061.000000              11.900000
# 75%    36092.000000              12.850000
# max    36123.000000              20.900000
#
#        Average Number of Physically Unhealthy Days  \
# count                                    63.000000
# mean                                      3.008505
# std                                       0.278670
# min                                       2.287459
# 25%                                       2.865299
# 50%                                       3.022177
# 75%                                       3.203251
# max                                       3.531088
#
#        Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# ...

# %%
# Find Range of each column

print('Range of % Fair or Poor Health:',ny['% Fair or Poor Health'].max()-ny['% Fair or Poor Health'].min())
print('Range of Average Number of Physically Unhealthy Days:',ny['Average Number of Physically Unhealthy Days'].max()-ny['Average Number of Physically Unhealthy Days'].min())
print('Range of Average Number of Mentally Unhealthy Days:',ny['Average Number of Mentally Unhealthy Days'].max()-ny['Average Number of Mentally Unhealthy Days'].min())
print('Range of % Low Birthweight:',ny['% Low Birthweight'].max()-ny['% Low Birthweight'].min())
print('Range of % Adults with Obesity:',ny['% Adults with Obesity'].max()-ny['% Adults with Obesity'].min())
print('Range of Food Environment Index:',ny['Food Environment Index'].max()-ny['Food Environment Index'].min())
print('Range of % Physically Inactive:',ny['% Physically Inactive'].max()-ny['% Physically Inactive'].min())
print('Range of % With Access to Exercise Opportunities:',ny['% With Access to Exercise Opportunities'].max()-ny['% With Access to Exercise Opportunities'].min())
print('Range of % Driving Deaths with Alcohol Involvement:',ny['% Driving Deaths with Alcohol Involvement'].max()-ny['% Driving Deaths with Alcohol Involvement'].min())
print('Range of Average Daily PM2.5:',ny['Average Daily PM2.5'].max()-ny['Average Daily PM2.5'].min())
print('Range of % Drive Alone to Work',ny['% Drive Alone to Work'].max()-ny['% Drive Alone to Work'].min())
print('Range of % Long Commute - Drives Alone',ny['% Long Commute - Drives Alone'].max()-ny['% Long Commute - Drives Alone'].min())
# Out:
# Range of % Fair or Poor Health: 11.899999999999999
# Range of Average Number of Physically Unhealthy Days: 1.2436290349
# Range of Average Number of Mentally Unhealthy Days: 1.3018430138000001
# Range of % Low Birthweight: 5.210693833600001
# Range of % Adults with Obesity: 17.700000000000003
# Range of Food Environment Index: 3.3999999999999995
# Range of % Physically Inactive: 18.700000000000003
# Range of % With Access to Exercise Opportunities: 63.104933701
# Range of % Driving Deaths with Alcohol Involvement: 56.25
# Range of Average Daily PM2.5: 3.3999999999999995
# Range of % Drive Alone to Work 77.8852970148
# Range of % Long Commute - Drives Alone 52.0

# %% [markdown]
# ### Data Wrangling

# %%
print(ca.isna().sum())
# Out:
# FIPS                                            0
# State                                           0
# County                                          1
# Unreliable                                     57
# % Fair or Poor Health                           0
# Average Number of Physically Unhealthy Days     0
# Average Number of Mentally Unhealthy Days       0
# % Low Birthweight                               1
# % Adults with Obesity                           0
# Food Environment Index                          0
# % Physically Inactive                           0
# % With Access to Exercise Opportunities         0
# % Driving Deaths with Alcohol Involvement       0
# Average Daily PM2.5                             0
# % Drive Alone to Work                           0
# % Long Commute - Drives Alone                   0
# dtype: int64

# %%
print(tx.isna().sum())
# Out:
# FIPS                                             0
# State                                            0
# County                                           1
# Unreliable                                     224
# % Fair or Poor Health                            1
# Average Number of Physically Unhealthy Days      1
# Average Number of Mentally Unhealthy Days        1
# % Low Birthweight                               19
# % Adults with Obesity                            1
# Food Environment Index                           1
# % Physically Inactive                            1
# % With Access to Exercise Opportunities         13
# % Driving Deaths with Alcohol Involvement        0
# Average Daily PM2.5                              0
# % Drive Alone to Work                            0
# % Long Commute - Drives Alone                    0
# dtype: int64

# %%
print(ny.isna().sum())
# Out:
# FIPS                                            0
# State                                           0
# County                                          1
# Unreliable                                     62
# % Fair or Poor Health                           0
# Average Number of Physically Unhealthy Days     0
# Average Number of Mentally Unhealthy Days       0
# % Low Birthweight                               0
# % Adults with Obesity                           0
# Food Environment Index                          0
# % Physically Inactive                           0
# % With Access to Exercise Opportunities         0
# % Driving Deaths with Alcohol Involvement       0
# Average Daily PM2.5                             0
# % Drive Alone to Work                           0
# % Long Commute - Drives Alone                   0
# dtype: int64

# %%
print(ca["% Low Birthweight"].isnull())
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# Name: % Low Birthweight, dtype: bool

# %%
ca.drop(2, inplace = True)
ca.reindex()
# Out:
# /var/folders/rv/0q6lgvm90d18dy_bd145ywlh0000gn/T/ipykernel_2431/2583567261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca.drop(2, inplace = True)
#     FIPS       State           County Unreliable  % Fair or Poor Health  \
# 0   6000  California              NaN        NaN                   14.4
# 1   6001  California          Alameda        NaN                   11.7
# 3   6005  California           Amador        NaN                   13.4
# 4   6007  California            Butte        NaN                   15.4
# 5   6009  California        Calaveras        NaN                   14.1
# 6   6011  California           Colusa        NaN                   19.2
# 7   6013  California     Contra Costa        NaN                   12.1
# ...

# %%
print(ca.isna().sum())
# Out:
# FIPS                                            0
# State                                           0
# County                                          1
# Unreliable                                     57
# % Fair or Poor Health                           0
# Average Number of Physically Unhealthy Days     0
# Average Number of Mentally Unhealthy Days       0
# % Low Birthweight                               0
# % Adults with Obesity                           0
# Food Environment Index                          0
# % Physically Inactive                           0
# % With Access to Exercise Opportunities         0
# % Driving Deaths with Alcohol Involvement       0
# Average Daily PM2.5                             0
# % Drive Alone to Work                           0
# % Long Commute - Drives Alone                   0
# dtype: int64

# %%
tx.dropna(subset=['% Low Birthweight'], inplace=True)
tx.dropna(subset=['% With Access to Exercise Opportunities'], inplace=True)
tx.dropna(subset=['Food Environment Index'], inplace=True)
tx.reindex()
# Out:
# /var/folders/rv/0q6lgvm90d18dy_bd145ywlh0000gn/T/ipykernel_2431/3715443469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tx.dropna(subset=['% Low Birthweight'], inplace=True)
# /var/folders/rv/0q6lgvm90d18dy_bd145ywlh0000gn/T/ipykernel_2431/3715443469.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tx.dropna(subset=['% With Access to Exercise Opportunities'], inplace=True)
# /var/folders/rv/0q6lgvm90d18dy_bd145ywlh0000gn/T/ipykernel_2431/3715443469.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
print(tx.isna().sum())
# Out:
# FIPS                                             0
# State                                            0
# County                                           1
# Unreliable                                     205
# % Fair or Poor Health                            0
# Average Number of Physically Unhealthy Days      0
# Average Number of Mentally Unhealthy Days        0
# % Low Birthweight                                0
# % Adults with Obesity                            0
# Food Environment Index                           0
# % Physically Inactive                            0
# % With Access to Exercise Opportunities          0
# % Driving Deaths with Alcohol Involvement        0
# Average Daily PM2.5                              0
# % Drive Alone to Work                            0
# % Long Commute - Drives Alone                    0
# dtype: int64

# %%
ca.head()
# Out:
#    FIPS       State     County Unreliable  % Fair or Poor Health  \
# 0  6000  California        NaN        NaN                   14.4
# 1  6001  California    Alameda        NaN                   11.7
# 3  6005  California     Amador        NaN                   13.4
# 4  6007  California      Butte        NaN                   15.4
# 5  6009  California  Calaveras        NaN                   14.1
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     2.964399
# 1                                     2.592017
# 3                                     3.243942
# 4                                     3.543488
# 5                                     3.406670
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 0                                   4.030544           6.889022
# 1                                   4.521002           7.154935
# 3                                   4.933832           5.989459
# ...

# %%
tx.head()
# Out:
#     FIPS  State    County Unreliable  % Fair or Poor Health  \
# 0  48000  Texas       NaN        NaN                   15.7
# 1  48001  Texas  Anderson        NaN                   19.8
# 2  48003  Texas   Andrews        NaN                   19.7
# 3  48005  Texas  Angelina        NaN                   20.6
# 4  48007  Texas   Aransas        NaN                   19.7
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     2.922101
# 1                                     3.878645
# 2                                     3.778131
# 3                                     4.068346
# 4                                     4.043917
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 0                                   4.175881           8.341789
# 1                                   4.725674           7.356547
# 2                                   4.708524           7.317073
# ...

# %%
health = pd.concat([ca, tx, ny])
health.head()
# Out:
#    FIPS       State     County Unreliable  % Fair or Poor Health  \
# 0  6000  California        NaN        NaN                   14.4
# 1  6001  California    Alameda        NaN                   11.7
# 3  6005  California     Amador        NaN                   13.4
# 4  6007  California      Butte        NaN                   15.4
# 5  6009  California  Calaveras        NaN                   14.1
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     2.964399
# 1                                     2.592017
# 3                                     3.243942
# 4                                     3.543488
# 5                                     3.406670
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 0                                   4.030544           6.889022
# 1                                   4.521002           7.154935
# 3                                   4.933832           5.989459
# ...

# %%
health.tail()
# Out:
#      FIPS     State       County Unreliable  % Fair or Poor Health  \
# 58  36115  New York   Washington        NaN                   12.4
# 59  36117  New York        Wayne        NaN                   11.8
# 60  36119  New York  Westchester        NaN                   10.2
# 61  36121  New York      Wyoming        NaN                   11.6
# 62  36123  New York        Yates        NaN                   12.8
#
#     Average Number of Physically Unhealthy Days  \
# 58                                     3.098140
# 59                                     3.107184
# 60                                     2.503443
# 61                                     2.939329
# 62                                     3.282754
#
#     Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 58                                   4.765997           7.393293
# 59                                   4.745084           7.201925
# 60                                   4.176269           7.970133
# ...

# %%
health.corr (numeric_only = True)
# Out:
#                                                  FIPS  % Fair or Poor Health  \
# FIPS                                         1.000000               0.373688
# % Fair or Poor Health                        0.373688               1.000000
# Average Number of Physically Unhealthy Days  0.386134               0.943909
# Average Number of Mentally Unhealthy Days    0.110159               0.353548
# % Low Birthweight                            0.416529               0.351838
# % Adults with Obesity                        0.608461               0.860762
# Food Environment Index                      -0.380512              -0.708471
# % Physically Inactive                        0.524416               0.920414
# % With Access to Exercise Opportunities     -0.381333              -0.334281
# % Driving Deaths with Alcohol Involvement   -0.258760              -0.067562
# Average Daily PM2.5                          0.061836               0.151711
# ...

# %%
health['County'] = health['County'].astype(str)
health.dtypes
# Out:
# FIPS                                             int64
# State                                           object
# County                                          object
# Unreliable                                      object
# % Fair or Poor Health                          float64
# Average Number of Physically Unhealthy Days    float64
# Average Number of Mentally Unhealthy Days      float64
# % Low Birthweight                              float64
# % Adults with Obesity                          float64
# Food Environment Index                         float64
# % Physically Inactive                          float64
# % With Access to Exercise Opportunities        float64
# % Driving Deaths with Alcohol Involvement      float64
# Average Daily PM2.5                            float64
# % Drive Alone to Work                          float64
# % Long Commute - Drives Alone                  float64
# dtype: object

# %%
health['County'] = health['County'].apply(lambda x: x + " County")
health.head()
# Out:
#    FIPS       State            County Unreliable  % Fair or Poor Health  \
# 0  6000  California        nan County        NaN                   14.4
# 1  6001  California    Alameda County        NaN                   11.7
# 3  6005  California     Amador County        NaN                   13.4
# 4  6007  California      Butte County        NaN                   15.4
# 5  6009  California  Calaveras County        NaN                   14.1
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     2.964399
# 1                                     2.592017
# 3                                     3.243942
# 4                                     3.543488
# 5                                     3.406670
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# 0                                   4.030544           6.889022
# 1                                   4.521002           7.154935
# ...

# %%
health.sort_values('County')
# Out:
#       FIPS       State           County Unreliable  % Fair or Poor Health  \
# 1     6001  California   Alameda County        NaN                   11.7
# 1    36001    New York    Albany County        NaN                   10.4
# 2    36003    New York  Allegany County        NaN                   12.6
# 3     6005  California    Amador County        NaN                   13.4
# 1    48001       Texas  Anderson County        NaN                   19.8
# ..     ...         ...              ...        ...                    ...
# 58    6115  California      Yuba County        NaN                   16.8
# 253  48505       Texas    Zapata County        NaN                   31.0
# 0    48000       Texas       nan County        NaN                   15.7
# 0    36000    New York       nan County        NaN                   11.8
# 0     6000  California       nan County        NaN                   14.4
#
#      Average Number of Physically Unhealthy Days  \
# ...

# %% [markdown]
# # Correlation with Both Datasets

# %%
grouped = pd.read_csv('grouped.csv')
grouped.head()
# Out:
#    Unnamed: 0      COUNTY_NAME  STATE_NAME   FIPS  NatWalkInd         D4A  \
# 0           0   Alameda County  California   6001   14.138809  377.770332
# 1           1    Albany County    New York  36001   11.404965  422.265939
# 2           2  Allegany County    New York  36003    5.132576  654.465000
# 3           3    Alpine County  California   6003    4.833333         NaN
# 4           4    Amador County  California   6005    6.535714  785.360000
#
#         TotEmp       TotPop  D2A_JPHH           D5AR   CBSA_POP   CBSA_EMP  \
# 0   753.440306  1569.914040  1.824694  140333.749761  4673221.0  2400290.0
# 1  1010.553191  1308.195745  7.668180   49466.906383   880481.0   447103.0
# 2   322.363636  1068.750000  0.746258    2019.886364        0.0        0.0
# 3   274.500000   573.000000  1.857263     462.000000        0.0        0.0
# 4   424.071429  1351.035714  1.043397    1294.428571        0.0        0.0
#
# ...

# %%
grouped.rename(columns={"COUNTY_NAME": "County"}, inplace = True)
grouped.head()
# Out:
#    Unnamed: 0           County  STATE_NAME   FIPS  NatWalkInd         D4A  \
# 0           0   Alameda County  California   6001   14.138809  377.770332
# 1           1    Albany County    New York  36001   11.404965  422.265939
# 2           2  Allegany County    New York  36003    5.132576  654.465000
# 3           3    Alpine County  California   6003    4.833333         NaN
# 4           4    Amador County  California   6005    6.535714  785.360000
#
#         TotEmp       TotPop  D2A_JPHH           D5AR   CBSA_POP   CBSA_EMP  \
# 0   753.440306  1569.914040  1.824694  140333.749761  4673221.0  2400290.0
# 1  1010.553191  1308.195745  7.668180   49466.906383   880481.0   447103.0
# 2   322.363636  1068.750000  0.746258    2019.886364        0.0        0.0
# 3   274.500000   573.000000  1.857263     462.000000        0.0        0.0
# 4   424.071429  1351.035714  1.043397    1294.428571        0.0        0.0
#
# ...

# %%
merged_df = pd.merge(health, grouped, on='FIPS')
merged_df = merged_df.drop(columns = ['County_y', 'STATE_NAME'])
merged_df = merged_df.rename(columns = {'County_x':'County'})
merged_df.columns
# Out:
# Index(['FIPS', 'State', 'County', 'Unreliable', '% Fair or Poor Health',
#        'Average Number of Physically Unhealthy Days',
#        'Average Number of Mentally Unhealthy Days', '% Low Birthweight',
#        '% Adults with Obesity', 'Food Environment Index',
#        '% Physically Inactive', '% With Access to Exercise Opportunities',
#        '% Driving Deaths with Alcohol Involvement', 'Average Daily PM2.5',
#        '% Drive Alone to Work', '% Long Commute - Drives Alone', 'Unnamed: 0',
#        'NatWalkInd', 'D4A', 'TotEmp', 'TotPop', 'D2A_JPHH', 'D5AR', 'CBSA_POP',
#        'CBSA_EMP', 'Pct_AO0', 'D4C', 'Pct_AO1', 'Pct_AO2p', 'D3APO', 'D3AAO',
#        'D4D'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)
item = merged_df.corr (numeric_only = True)
item

corr = item

thresh = 0.4

mask = corr.abs().gt(thresh)

x = corr.where(mask).stack()
x.to_csv('corr.csv')

item
# Out:
#                                                  FIPS  % Fair or Poor Health  \
# FIPS                                         1.000000               0.373321
# % Fair or Poor Health                        0.373321               1.000000
# Average Number of Physically Unhealthy Days  0.385946               0.945393
# Average Number of Mentally Unhealthy Days    0.098794               0.347624
# % Low Birthweight                            0.415197               0.353458
# % Adults with Obesity                        0.608994               0.860498
# Food Environment Index                      -0.374659              -0.709629
# % Physically Inactive                        0.522730               0.921738
# % With Access to Exercise Opportunities     -0.378659              -0.329588
# % Driving Deaths with Alcohol Involvement   -0.258872              -0.068007
# Average Daily PM2.5                          0.057954               0.149273
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

X = merged_df[['NatWalkInd']]
Y = merged_df['% With Access to Exercise Opportunities']

lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
print('R^2 = ', lm.score(X,Y))
# Out:
# R^2 =  0.420838517776297

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.regplot(data = merged_df, x = 'NatWalkInd', y = '% With Access to Exercise Opportunities')
plt.ylim(0,)
plt.show()

# %%
sns.residplot(x= merged_df['NatWalkInd'], y = merged_df['% With Access to Exercise Opportunities'])
plt.show()

# %%
def PlotPoly(model, x, y, Name):
    x_new = np.linspace(x.min(), x.max(), 1000)
    y_new = model(x_new)

    plt.plot(x, y, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898,0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('NatWalkInd')

    plt.show()

# %%
x = merged_df['% With Access to Exercise Opportunities']
y = merged_df['NatWalkInd']
f = np.polyfit(x,y,2)
p = np.poly1d (f)
PlotPoly(p,x,y, '% With Access to Exercise Opportunities')

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

X = merged_df[['NatWalkInd']]
Y = merged_df['% Adults with Obesity']

lm.fit(X,Y)
print('R^2 = ', lm.score(X,Y))
# Out:
# R^2 =  0.2517606887610856

# %%
sns.regplot(data = merged_df, x = 'NatWalkInd', y = '% Adults with Obesity')
plt.ylim(0,)
plt.show()

# %%
sns.residplot(x= merged_df['NatWalkInd'], y = merged_df['% Adults with Obesity'])
plt.show()

# %%
merged_df.to_csv('final_merge.csv', index = False)
